# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
from test import sample_now, main, build_conf

# %%
conf_arg = build_conf("face_choice", "face", 50, 1, jump_length=5, jump_n_sample=5)
p, ani = main(conf_arg)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Done
